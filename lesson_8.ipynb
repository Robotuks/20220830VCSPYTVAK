# %%
# True and not False and ( [] or bool(" ") ) or "word".isdigit()
# not False and ( [] or bool(" ") ) or "word".isdigit()
# ( [] or bool(" ") ) or "word".isdigit() # ( False or True ) or "word".isdigit()
True or "word".isdigit()
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %%
getSum(1)

def getSum(x):
    return x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Robotux\Documents\Python\20220830VCSPYTVAK\lesson_8.ipynb Cell 4 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Robotux/Documents/Python/20220830VCSPYTVAK/lesson_8.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> getSum(1)
#       <a href='vscode-notebook-cell:/c%3A/Users/Robotux/Documents/Python/20220830VCSPYTVAK/lesson_8.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> def getSum(x):
#       <a href='vscode-notebook-cell:/c%3A/Users/Robotux/Documents/Python/20220830VCSPYTVAK/lesson_8.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     return x
#
# NameError: name 'getSum' is not defined

# %%
def getSum(x):
    return x

getSum(1)
# Out:
# 1

# %% [markdown]
# # Namų darbai 3

# %%
# 1 uzduotis
def analyze_txt(txt_imputed: str):
    letters = numbers = spaces = symbols = 0
    for character in txt_imputed:
        if character.isalpha():
            letters += 1
        elif character.isdigit():
            numbers += 1
        elif character.isspace():
            spaces += 1
        else:
            symbols += 1
    return letters, numbers, spaces, symbols

text = 'vienas 2 ??'
letters, numbers, spaces, symbols = analyze_txt(text)
print (f"Letters: {letters}, numbers: {numbers}, spaces: {spaces}, symbols: {symbols}.")
# Out:
# Letters: 6, numbers: 1, spaces: 2, symbols: 2.

# %%
import string

print (string.ascii_letters)
print (string.printable)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
# 2 uzduotis 
def list_maker(start, end, step):
    list_made = list(range(start, end, step))
    return list_made

list_start = int(input("Enter start number: "))
list_end = int(input("Enter end number: "))
list_step = int(input("Enter step: "))

list_maker(list_start, list_end, list_step)
# Out:
# [5, 59, 113, 167, 221, 275, 329]

# %%
# 3 uzduotis 
list_1 = [7, 5, 4, 2, 9, 3]

def function_1(list_inputed):
    list_inputed.sort()
    smallest_num = list_inputed[0]
    biggest_num = list_inputed[-1]
    difference = biggest_num - smallest_num
    return (f"The difference between the smallest ({smallest_num}) and the biggest ({biggest_num}) numbers on the list was {difference}")

def function_2(list_inputed):
    smallest_num = min(list_inputed)
    biggest_num = max(list_inputed)
    return  biggest_num - smallest_num

print (function_1(list_1))
print (function_2(list_1))
# Out:
# The difference between the smallest (2) and the biggest (9) numbers on the list was 7
# 7

# %% [markdown]
# # Pandas

# %%
import pandas as pd

df_2 = pd.DataFrame(
    [ ['Jan',58,42,74,22,2.05],
    ['Feb',61,45,78,26,3.02],
    ['Mar',65,48,84,25,2.34],
    ['Apr',67,50,92,28,1.02],
    ['May',71,53,98,35,0.48],
    ['Jun',75,56,107,41,0.11],
    ['Jul',77,58,105,44,0.0],
    ['Aug',77,59,102,43,0.03],
    ['Sep',77,57,103,40,0.17],
    ['Oct',73,54,96,34,0.81],
    ['Nov',64,48,84,30,1.7],
    ['Dec',58,None,None,21,2.56],
    ['Dec',58,42,73,21,2.56] ],
    columns = ['month','avg_high','avg_low','record_high','record_low','avg_precipitation'])

# %%
df_2
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              13 non-null     object
#  1   avg_high           13 non-null     int64
#  2   avg_low            12 non-null     float64
#  3   record_high        12 non-null     float64
#  4   record_low         13 non-null     int64
#  5   avg_precipitation  13 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 752.0+ bytes

# %%
df_2.describe()
# Out:
#         avg_high    avg_low  record_high  record_low  avg_precipitation
# count  13.000000  12.000000    12.000000   13.000000          13.000000
# mean   67.769231  51.000000    91.333333   31.538462           1.296154
# std     7.639305   6.060303    12.323911    8.501131           1.115210
# min    58.000000  42.000000    73.000000   21.000000           0.000000
# 25%    61.000000  47.250000    82.500000   25.000000           0.170000
# 50%    67.000000  51.500000    94.000000   30.000000           1.020000
# 75%    75.000000  56.250000   102.250000   40.000000           2.340000
# max    77.000000  59.000000   107.000000   44.000000           3.020000

# %%
df_2.head()
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0   Jan        58     42.0         74.0          22               2.05
# 1   Feb        61     45.0         78.0          26               3.02
# 2   Mar        65     48.0         84.0          25               2.34
# 3   Apr        67     50.0         92.0          28               1.02
# 4   May        71     53.0         98.0          35               0.48

# %%
df_2.tail()
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# 12   Dec        58     42.0         73.0          21               2.56

# %%
list(df_2.columns)
# Out:
# ['month',
#  'avg_high',
#  'avg_low',
#  'record_high',
#  'record_low',
#  'avg_precipitation']

# %%
# df_2.sort_values( 'avg_precipitation' )
df_2.sort_values( 'avg_high', ascending=False )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 5    Jun        75     56.0        107.0          41               0.11
# 9    Oct        73     54.0         96.0          34               0.81
# 4    May        71     53.0         98.0          35               0.48
# 3    Apr        67     50.0         92.0          28               1.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 1    Feb        61     45.0         78.0          26               3.02
# 0    Jan        58     42.0         74.0          22               2.05
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
# df_2.sort_values( ['avg_high', 'avg_low'], ascending=False )
df_2.sort_values( ['avg_high', 'avg_low'], ascending=[True, False] )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# 11   Dec        58      NaN          NaN          21               2.56
# 1    Feb        61     45.0         78.0          26               3.02
# 10   Nov        64     48.0         84.0          30               1.70
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 5    Jun        75     56.0        107.0          41               0.11
# 7    Aug        77     59.0        102.0          43               0.03
# 6    Jul        77     58.0        105.0          44               0.00
# ...

# %%
df_3 = df_2.sort_values( ['avg_high', 'avg_low'], ascending=[True, False] )
df_3
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# 11   Dec        58      NaN          NaN          21               2.56
# 1    Feb        61     45.0         78.0          26               3.02
# 10   Nov        64     48.0         84.0          30               1.70
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 5    Jun        75     56.0        107.0          41               0.11
# 7    Aug        77     59.0        102.0          43               0.03
# 6    Jul        77     58.0        105.0          44               0.00
# ...

# %%
print (df_3[ 'avg_high' ] )
print (type( df_3[ 'avg_high' ] ) )
# Out:
# 0     58
# 12    58
# 11    58
# 1     61
# 10    64
# 2     65
# 3     67
# 4     71
# 9     73
# 5     75
# 7     77
# 6     77
# 8     77
# Name: avg_high, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
df_3[ ['avg_high', 'avg_low' ] ]
print (df_3[ ['avg_high', 'avg_low' ] ])
print (type( df_3[ ['avg_high', 'avg_low' ] ] ) )
# Out:
#     avg_high  avg_low
# 0         58     42.0
# 12        58     42.0
# 11        58      NaN
# 1         61     45.0
# 10        64     48.0
# 2         65     48.0
# 3         67     50.0
# 4         71     53.0
# 9         73     54.0
# 5         75     56.0
# 7         77     59.0
# 6         77     58.0
# 8         77     57.0
# <class 'pandas.core.frame.DataFrame'>

# %%
# Out:
# 0      74.0
# 12     73.0
# 11      NaN
# 1      78.0
# 10     84.0
# 2      84.0
# 3      92.0
# 4      98.0
# 9      96.0
# 5     107.0
# 7     102.0
# 6     105.0
# 8     103.0
# Name: record_high, dtype: float64

# %%
df_3['naujas stulpelis'] = 5

# %%
df_3['naujas stulpelis']
# Out:
# 0     5
# 12    5
# 11    5
# 1     5
# 10    5
# 2     5
# 3     5
# 4     5
# 9     5
# 5     5
# 7     5
# 6     5
# 8     5
# Name: naujas stulpelis, dtype: int64

# %%
# df_3.naujas stulpelis # Nerekomenduoju 
df_3.avg_high
# Out:
# 0     58
# 12    58
# 11    58
# 1     61
# 10    64
# 2     65
# 3     67
# 4     71
# 9     73
# 5     75
# 7     77
# 6     77
# 8     77
# Name: avg_high, dtype: int64

# %%
df_3
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# 11   Dec        58      NaN          NaN          21               2.56
# 1    Feb        61     45.0         78.0          26               3.02
# 10   Nov        64     48.0         84.0          30               1.70
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 5    Jun        75     56.0        107.0          41               0.11
# 7    Aug        77     59.0        102.0          43               0.03
# 6    Jul        77     58.0        105.0          44               0.00
# ...

# %%
df_3.loc[7]
# Out:
# month                  Aug
# avg_high                77
# avg_low               59.0
# record_high          102.0
# record_low              43
# avg_precipitation     0.03
# naujas stulpelis         5
# Name: 7, dtype: object

# %%
df_3.loc[: , 'avg_high' ]
# Out:
# 0     58
# 12    58
# 11    58
# 1     61
# 10    64
# 2     65
# 3     67
# 4     71
# 9     73
# 5     75
# 7     77
# 6     77
# 8     77
# Name: avg_high, dtype: int64

# %%
df_3.loc[ [7,10] ]
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 7    Aug        77     59.0        102.0          43               0.03
# 10   Nov        64     48.0         84.0          30               1.70
#
#     naujas stulpelis
# 7                  5
# 10                 5

# %%
df_3
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# 11   Dec        58      NaN          NaN          21               2.56
# 1    Feb        61     45.0         78.0          26               3.02
# 10   Nov        64     48.0         84.0          30               1.70
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 5    Jun        75     56.0        107.0          41               0.11
# 7    Aug        77     59.0        102.0          43               0.03
# 6    Jul        77     58.0        105.0          44               0.00
# ...

# %%
df_3.iloc[ [1,2,3,4] ] # row number from top of the table
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 12   Dec        58     42.0         73.0          21               2.56
# 11   Dec        58      NaN          NaN          21               2.56
# 1    Feb        61     45.0         78.0          26               3.02
# 10   Nov        64     48.0         84.0          30               1.70
#
#     naujas stulpelis
# 12                 5
# 11                 5
# 1                  5
# 10                 5

# %%
df_3.loc[ [1,2,3,4] ] # index name
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 1   Feb        61     45.0         78.0          26               3.02
# 2   Mar        65     48.0         84.0          25               2.34
# 3   Apr        67     50.0         92.0          28               1.02
# 4   May        71     53.0         98.0          35               0.48
#
#    naujas stulpelis
# 1                 5
# 2                 5
# 3                 5
# 4                 5

# %%
df_3.loc[1] # index name
# Out:
# month                 Feb
# avg_high               61
# avg_low              45.0
# record_high          78.0
# record_low             26
# avg_precipitation    3.02
# naujas stulpelis        5
# Name: 1, dtype: object

# %%
# df_3[1] # error

# %%
df_3
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# 11   Dec        58      NaN          NaN          21               2.56
# 1    Feb        61     45.0         78.0          26               3.02
# 10   Nov        64     48.0         84.0          30               1.70
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 5    Jun        75     56.0        107.0          41               0.11
# 7    Aug        77     59.0        102.0          43               0.03
# 6    Jul        77     58.0        105.0          44               0.00
# ...

# %%
df_indexed = df_3.set_index('month')
df_indexed
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
# Dec          58      NaN          NaN          21               2.56
# Feb          61     45.0         78.0          26               3.02
# Nov          64     48.0         84.0          30               1.70
# Mar          65     48.0         84.0          25               2.34
# Apr          67     50.0         92.0          28               1.02
# May          71     53.0         98.0          35               0.48
# Oct          73     54.0         96.0          34               0.81
# Jun          75     56.0        107.0          41               0.11
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# ...

# %%
# df_indexed.loc[ 'Nov' ]
df_indexed.loc[ 'Dec' ]
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Dec          58     42.0         73.0          21               2.56
# Dec          58      NaN          NaN          21               2.56
#
#        naujas stulpelis
# month
# Dec                   5
# Dec                   5

# %%
df_indexed.iloc[ 0:2 ]
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
#
#        naujas stulpelis
# month
# Jan                   5
# Dec                   5

# %%
df_indexed.loc[ 'Dec', 'record_high' ]
# Out:
# month
# Dec    73.0
# Dec     NaN
# Name: record_high, dtype: float64

# %%
df_indexed.loc[ ['Dec', 'Jan'], 'record_high' ]
# Out:
# month
# Dec    73.0
# Dec     NaN
# Jan    74.0
# Name: record_high, dtype: float64

# %%
# df_indexed.loc[ <index values>, <column names> ]
df_indexed.loc[ ['Dec', 'Jan'], ['record_high', 'avg_high'] ]
# Out:
#        record_high  avg_high
# month
# Dec           73.0        58
# Dec            NaN        58
# Jan           74.0        58

# %%
df_indexed.loc[  :, ['record_high', 'avg_high'] ] # : means everything
# Out:
#        record_high  avg_high
# month
# Jan           74.0        58
# Dec           73.0        58
# Dec            NaN        58
# Feb           78.0        61
# Nov           84.0        64
# Mar           84.0        65
# Apr           92.0        67
# May           98.0        71
# Oct           96.0        73
# Jun          107.0        75
# Aug          102.0        77
# Jul          105.0        77
# Sep          103.0        77

# %%
# df_indexed.drop_duplicates() # drop identical rows
df_indexed.drop_duplicates( ['avg_high', 'record_low'] ) # drop identical rows
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
# Feb          61     45.0         78.0          26               3.02
# Nov          64     48.0         84.0          30               1.70
# Mar          65     48.0         84.0          25               2.34
# Apr          67     50.0         92.0          28               1.02
# May          71     53.0         98.0          35               0.48
# Oct          73     54.0         96.0          34               0.81
# Jun          75     56.0        107.0          41               0.11
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# Sep          77     57.0        103.0          40               0.17
#
#        naujas stulpelis
# month
# Jan                   5
# ...

# %%
df_indexed.reset_index().drop_duplicates('month')
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Dec        58     42.0         73.0          21               2.56
# 3    Feb        61     45.0         78.0          26               3.02
# 4    Nov        64     48.0         84.0          30               1.70
# 5    Mar        65     48.0         84.0          25               2.34
# 6    Apr        67     50.0         92.0          28               1.02
# 7    May        71     53.0         98.0          35               0.48
# 8    Oct        73     54.0         96.0          34               0.81
# 9    Jun        75     56.0        107.0          41               0.11
# 10   Aug        77     59.0        102.0          43               0.03
# 11   Jul        77     58.0        105.0          44               0.00
# 12   Sep        77     57.0        103.0          40               0.17
#
#     naujas stulpelis
# ...

# %%
df_indexed.reset_index()
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Dec        58     42.0         73.0          21               2.56
# 2    Dec        58      NaN          NaN          21               2.56
# 3    Feb        61     45.0         78.0          26               3.02
# 4    Nov        64     48.0         84.0          30               1.70
# 5    Mar        65     48.0         84.0          25               2.34
# 6    Apr        67     50.0         92.0          28               1.02
# 7    May        71     53.0         98.0          35               0.48
# 8    Oct        73     54.0         96.0          34               0.81
# 9    Jun        75     56.0        107.0          41               0.11
# 10   Aug        77     59.0        102.0          43               0.03
# 11   Jul        77     58.0        105.0          44               0.00
# ...

# %%
df_indexed.reset_index().duplicated('month')
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# dtype: bool

# %%
df_indexed
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
# Dec          58      NaN          NaN          21               2.56
# Feb          61     45.0         78.0          26               3.02
# Nov          64     48.0         84.0          30               1.70
# Mar          65     48.0         84.0          25               2.34
# Apr          67     50.0         92.0          28               1.02
# May          71     53.0         98.0          35               0.48
# Oct          73     54.0         96.0          34               0.81
# Jun          75     56.0        107.0          41               0.11
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# ...

# %%
df_indexed.isnull()

# %%
df_indexed.groupby('month').sum()
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Apr          67     50.0         92.0          28               1.02
# Aug          77     59.0        102.0          43               0.03
# Dec         116     42.0         73.0          42               5.12
# Feb          61     45.0         78.0          26               3.02
# Jan          58     42.0         74.0          22               2.05
# Jul          77     58.0        105.0          44               0.00
# Jun          75     56.0        107.0          41               0.11
# Mar          65     48.0         84.0          25               2.34
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Sep          77     57.0        103.0          40               0.17
#
#        naujas stulpelis
# month
# Apr                   5
# ...

# %%
df_indexed.groupby('month')['avg_high', 'record_low'].sum()
# Out:
# C:\Users\Robotux\AppData\Local\Temp\ipykernel_30808\2466656867.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_indexed.groupby('month')['avg_high', 'record_low'].sum()
#        avg_high  record_low
# month
# Apr          67          28
# Aug          77          43
# Dec         116          42
# Feb          61          26
# Jan          58          22
# Jul          77          44
# Jun          75          41
# Mar          65          25
# May          71          35
# Nov          64          30
# Oct          73          34
# Sep          77          40

# %%
df_indexed = df_indexed.groupby('month').sum()
df_indexed
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Apr          67     50.0         92.0          28               1.02
# Aug          77     59.0        102.0          43               0.03
# Dec         116     42.0         73.0          42               5.12
# Feb          61     45.0         78.0          26               3.02
# Jan          58     42.0         74.0          22               2.05
# Jul          77     58.0        105.0          44               0.00
# Jun          75     56.0        107.0          41               0.11
# Mar          65     48.0         84.0          25               2.34
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Sep          77     57.0        103.0          40               0.17
#
#        naujas stulpelis
# month
# Apr                   5
# ...

# %%
df_indexed.to_csv('weather.csv')

# %%
df_read = pd.read_csv('weather.csv', index_col=0)
# df_read = pd.read_csv('weather.csv', index_col=[0,1])
df_read
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Apr          67     50.0         92.0          28               1.02
# Aug          77     59.0        102.0          43               0.03
# Dec         116     42.0         73.0          42               5.12
# Feb          61     45.0         78.0          26               3.02
# Jan          58     42.0         74.0          22               2.05
# Jul          77     58.0        105.0          44               0.00
# Jun          75     56.0        107.0          41               0.11
# Mar          65     48.0         84.0          25               2.34
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Sep          77     57.0        103.0          40               0.17
#
#        naujas stulpelis
# month
# Apr                   5
# ...

# %%
df_read['naujas_stulpelis_2'] = df_read['record_high'] + df_read['avg_low']
df_read
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Apr          67     50.0         92.0          28               1.02
# Aug          77     59.0        102.0          43               0.03
# Dec         116     42.0         73.0          42               5.12
# Feb          61     45.0         78.0          26               3.02
# Jan          58     42.0         74.0          22               2.05
# Jul          77     58.0        105.0          44               0.00
# Jun          75     56.0        107.0          41               0.11
# Mar          65     48.0         84.0          25               2.34
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Sep          77     57.0        103.0          40               0.17
#
#        naujas stulpelis  naujas_stulpelis_2
# month
# ...

# %%
# option 1 for dates
# df = pd.read_csv('LT.csv', parse_dates=['date'])
df = pd.read_csv('LT.csv')

# %%
# option 2 for dates
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    datetime64[ns]
#  1   home_team   367 non-null    object
#  2   away_team   367 non-null    object
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 23.1+ KB

# %%
df.describe()
# Out:
#        home_score  away_score
# count  367.000000  367.000000
# mean     1.547684    0.986376
# std      1.349879    1.172233
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      1.000000    1.000000
# 75%      2.000000    1.000000
# max      5.000000    7.000000

# %%
df.head(10)
# Out:
#         date   home_team  away_team  home_score  away_score  tourniment  \
# 0 1979-07-20  Kyrgyzstan  Lithuania           0           0    Friendly
# 1 1979-07-22     Georgia  Lithuania           5           0    Friendly
# 2 1979-07-24  Azerbaijan  Lithuania           0           1    Friendly
# 3 1979-07-28   Lithuania    Ukraine           0           2    Friendly
# 4 1979-07-30      Russia  Lithuania           2           0    Friendly
# 5 1979-08-01     Belarus  Lithuania           0           2    Friendly
# 6 1979-08-05      Russia  Lithuania           2           1    Friendly
# 7 1990-05-27     Georgia  Lithuania           2           2    Friendly
# 8 1991-11-15   Lithuania    Estonia           4           1  Baltic Cup
# 9 1991-11-17   Lithuania     Latvia           1           1  Baltic Cup
#
#        city       country
# 0    Moscow  Soviet Union
# 1    Moscow  Soviet Union
# 2    Moscow  Soviet Union
# 3    Moscow  Soviet Union
# 4    Moscow  Soviet Union
# ...

# %%
df.tail(10)
# Out:
#           date  home_team  away_team  home_score  away_score  \
# 357 2019-06-10     Serbia  Lithuania           4           1
# 358 2019-06-10     Serbia  Lithuania           4           1
# 359 2019-09-07  Lithuania    Ukraine           0           3
# 360 2019-09-07  Lithuania    Ukraine           0           3
# 361 2019-09-10  Lithuania   Portugal           1           5
# 362 2019-09-10  Lithuania   Portugal           1           5
# 363 2019-10-11    Ukraine  Lithuania           2           0
# 364 2019-10-11    Ukraine  Lithuania           2           0
# 365 2019-10-14  Lithuania     Serbia           1           2
# 366 2019-10-14  Lithuania     Serbia           1           2
#
#                   tourniment      city    country
# 357  UEFA Euro qualification  Belgrade     Serbia
# 358  UEFA Euro qualification  Belgrade     Serbia
# 359  UEFA Euro qualification   Vilnius  Lithuania
# 360  UEFA Euro qualification   Vilnius  Lithuania
# ...

# %%
df[ df['away_team'] == 'Lithuania' ]
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 4   1979-07-30      Russia  Lithuania           2           0
# 5   1979-08-01     Belarus  Lithuania           0           2
# ..         ...         ...        ...         ...         ...
# 354 2019-03-25  Azerbaijan  Lithuania           0           0
# 357 2019-06-10      Serbia  Lithuania           4           1
# 358 2019-06-10      Serbia  Lithuania           4           1
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
#
#                   tourniment      city       country
# 0                   Friendly    Moscow  Soviet Union
# 1                   Friendly    Moscow  Soviet Union
# 2                   Friendly    Moscow  Soviet Union
# ...

# %%
df['away_team'] == 'Lithuania' # mask
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 362    False
# 363     True
# 364     True
# 365    False
# 366    False
# Name: away_team, Length: 367, dtype: bool

# %%
df[ (df['away_team'] == 'Lithuania') & ( df['city'] == 'Kharkiv' ) & ( df['home_score'] > 2 ) ]
# Out:
#           date home_team  away_team  home_score  away_score tourniment  \
# 196 2010-05-25   Ukraine  Lithuania           4           0   Friendly
#
#         city  country
# 196  Kharkiv  Ukraine

# %%
# Atitikmenys tikrinant panariui - Bitwise operator
# and = &
# or = | 
# not = ~
# in = .isin()

# %%
df['away_team'] == 'Lithuania'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 362    False
# 363     True
# 364     True
# 365    False
# 366    False
# Name: away_team, Length: 367, dtype: bool

# %%
# skliaustai yra butini
df['city'].isin( ['Vilnius', 'Kharkiv'] ) & ( df['away_team'] == 'Lithuania' )
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 362    False
# 363     True
# 364     True
# 365    False
# 366    False
# Length: 367, dtype: bool

# %%
df[  df['city'].isin( ['Vilnius', 'Kharkiv'] ) ]
# Out:
#           date  home_team  away_team  home_score  away_score  \
# 18  1992-09-23  Lithuania    Denmark           0           0
# 19  1992-10-14  Lithuania   Slovakia           0           1
# 20  1992-10-28  Lithuania     Latvia           1           1
# 26  1993-04-14  Lithuania    Albania           3           1
# 27  1993-05-18  Lithuania    Ukraine           1           2
# ..         ...        ...        ...         ...         ...
# 362 2019-09-10  Lithuania   Portugal           1           5
# 363 2019-10-11    Ukraine  Lithuania           2           0
# 364 2019-10-11    Ukraine  Lithuania           2           0
# 365 2019-10-14  Lithuania     Serbia           1           2
# 366 2019-10-14  Lithuania     Serbia           1           2
#
#                        tourniment     city    country
# 18   FIFA World Cup qualification  Vilnius  Lithuania
# 19                       Friendly  Vilnius  Lithuania
# 20   FIFA World Cup qualification  Vilnius  Lithuania
# ...

# %%
# isfiltruoti kada LT zaide Kaune arba Vilniuje
# df[ (df['home_team'] == 'Lithuania')  & ( (df['city'] == 'Kaunas') | (df['city'] == 'Vilnius') ) ]
df[ (df['home_team'] == 'Lithuania') & df['city'].isin( ['Kaunas', 'Vilnius'] ) ]
# Out:
#           date  home_team away_team  home_score  away_score  \
# 17  1992-09-02  Lithuania   Georgia           1           0
# 18  1992-09-23  Lithuania   Denmark           0           0
# 19  1992-10-14  Lithuania  Slovakia           0           1
# 20  1992-10-28  Lithuania    Latvia           1           1
# 26  1993-04-14  Lithuania   Albania           3           1
# ..         ...        ...       ...         ...         ...
# 360 2019-09-07  Lithuania   Ukraine           0           3
# 361 2019-09-10  Lithuania  Portugal           1           5
# 362 2019-09-10  Lithuania  Portugal           1           5
# 365 2019-10-14  Lithuania    Serbia           1           2
# 366 2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment     city    country
# 17                       Friendly   Kaunas  Lithuania
# 18   FIFA World Cup qualification  Vilnius  Lithuania
# 19                       Friendly  Vilnius  Lithuania
# ...
